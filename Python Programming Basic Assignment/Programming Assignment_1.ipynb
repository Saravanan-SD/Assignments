# %%
#1. Write a Python program to print 'Hello Python'?

print("Hello Python")
# Out:
# Hello Python

# %%
#2. Write a Python program to do arithmetical operations addition and division.?

#addition
a=int(input())
b=int(input())
c=a+b
print(f'Sum is {c}')
# Out:
# 2
# 3
# Sum is 5

# %%
#Division
a=int(input())
b=int(input())

d=a/b
print(f'Division is {d}')
# Out:
# 4
# 5
# Division is 0.8

# %%
#3. Write a Python program to find the area of a triangle?

h=int(input('Please enter the height of triangle: '))
b=int(input('Please enter the base of triangle: '))
area=0.5*b*h

print(f'Area of the triangle is {area}')
# Out:
# Please enter the height of triangle: 3
# Please enter the base of triangle: 4
# Area of the triangle is 6.0

# %%
#4. Write a Python program to swap two variables?
a=int(input("Enter a variable,a: "))
b=int(input("Enter a variable,b: "))
temp=a
a=b
b=temp

print(f'Value of a is {a} and value of b is {b} after swapping')
# Out:
# Enter a variable,a: 23
# Enter a variable,b: 33
# Value of a is 33 and value of b is 23 after swapping

# %%
#5. Write a Python program to generate a random number?

import random

a=random.random()

print(a)
# Out:
# 0.8184237775577324
