# %% [raw]
# 1. Why are functions advantageous to have in your programs?
#
# Function reduce the need for duplicate codes and also increase code reusability.
# It also makes the codes shorter ,easier to read and easier to update.

# %% [raw]
# 2. When does the code in a function run: when it's specified or when it's called?
#
# The code in a function runs when the respective function is called.
#
# for Example
# Defining a function.
#
# def add(a,b):
#     return a+b
#
# Calling a function.
#
# add(4,5) will give output as 9

# %% [raw]
# 3. What statement creates a function?
#
# def statement followed by : defines a function.

# %% [raw]
# 4. What is the difference between a function and a function call?
#
# A function is a set of instruction given to a computer.
# A function call is used to call the defined function.

# %% [raw]
# 5. How many global scopes are there in a Python program? How many local scopes?
#
# There are 4 variable scopes. They are: Local,enclosing,global & Builtin

# %% [raw]
# 6. What happens to variables in a local scope when the function call returns?
#
# As the local variable is present inside the function and so when the function call returns the value of the function.
#
# For example
#
# def example(b):
#     a=10
#     return(a*b)
#
# Here the local scope is a=10 .when the above function is called it returns a mutiple of 10.

# %% [raw]
#  7. What is the concept of a return value? Is it possible to have a return value in an expression?
#
# return value is used to end the execution of a function call and return the result. Statement after this is not executed.
#
# return value cannot be used outside a function.

# %% [raw]
# 8. If a function does not have a return statement, what is the return value of a call to that function?
#
# Nothing will be returned
#
# for example
# def example(a,b):
#     a=10
#
# example(10,2) when the above function is called and executed nothing is shown as output.

# %% [raw]
# 9. How do you make a function variable refer to the global variable?
#
# we can use global keyword
#
# for example
# def e(b):
#     global a
#     a=10
#     return(a*b)

# %% [raw]
# 10. What is the data type of None?
#
# None is a None type object

# %% [raw]
# 11. What does the sentence import areallyourpetsnamederic do?
#
# This will give a error ModuleNotFoundError: No module named 'areallyourpetsnamederic'

# %% [raw]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?
#
# import spam as spam:
#
# bacon.spam()

# %% [raw]
# 13. What can you do to save a programme from crashing if it encounters an error?
#
# Error handling can be done by using try and except block to save a programme from crashing.

# %% [raw]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?
#
# A try block tests the code and if the code encounters a error the code inside the except block helps us to handle the error and saves the programme from crashing.
