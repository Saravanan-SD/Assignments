# %% [raw]
# 1. What exactly is []?
#
# [] the square bracket indicates a empty list.

# %%
#2. In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)

spam=[2, 4, 6, 8, 10]
spam.insert(2,'hello')
spam
# Out:
# [2, 4, 'hello', 6, 8, 10]

# %% [raw]
# Let's pretend the spam includes the list ['a','b','c','d'] for the next three queries.

# %% [raw]
# 3. What is the value of spam[int(int('3' * 2) / 11)]?
#
# spam[int(int('3' * 2) / 11)]
# Output=6

# %% [raw]
# 4. What is the value of spam[-1]?
# spam=['a','b','c','d']
# spam[-1]
# output is 'd'

# %% [raw]
# 5. What is the value of spam[:2]?
#
# output is ['a','b']

# %% [raw]
# Let's pretend bacon has the list [3.14, 'cat', 11, 'cat', True] for the next three questions.

# %% [raw]
# 6. What is the value of bacon.index('cat')?
#
# Index of 'cat' in bacon is 1 as index function returns the first occurence of the value.

# %% [raw]
# 7. How does bacon.append(99) change the look of the list value in bacon?
#
# After the operation 99 is added at the last.
#
# bacon=[3.14, 'cat', 11, 'cat', True, 99]

# %% [raw]
# 8. How does bacon.remove('cat') change the look of the list in bacon?
#
# bacon.remove('cat') removes the first occurence of the word cat.

# %% [raw]
# 9. What are the list concatenation and list replication operators?
#
# list concatenation operator is + and *
#
# list replication operator is *

# %% [raw]
# 10. What is difference between the list methods append() and insert()?
#
# Append adds a object at the end of the list.
#
# Whereas insert function can add a object at a given index.

# %% [raw]
# 11. What are the two methods for removing items from a list?
#
# Clear and remove

# %% [raw]
# 12.Describe how list values and string values are identical.
#
# Both string and list are ordered collection of character

# %% [raw]
# 13. What's the difference between tuples and lists?
# The key difference between the tuples and lists is that while the tuples are immutable objects the lists are mutable.

# %% [raw]
# 14. How do you type a tuple value that only contains the integer 42?
#
# To create a tuple with only one item, we have add a comma after the item.
# for example
#
# t=(42,)

# %%
#15. How do you get a list value's tuple form? How do you get a tuple value's list form?

#LIST VALUES IN TUPLE FORM
l=[2, 4, 6, 8, 10]

t=[x for x in zip(*[iter(l)])]

t
# Out:
# [(2,), (4,), (6,), (8,), (10,)]

# %%
#TUPLE VALUE IN LIST FORM
a=(1,2,3,4,5)
l1=list(zip(a))
l1
# Out:
# [(1,), (2,), (3,), (4,), (5,)]

# %% [raw]
# 16. Variables that 'contain' list values are not necessarily lists themselves. Instead, what do they
# contain?
#
# Lists can contain integers, float, strings, booleans,dictionary,tuple and set

# %% [raw]
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?
#
# when a copy is made using deepcopy,any changes made to a copy of object do not reflect in the original object.
#
# when a copy is made using copy,any changes made to a copy of object do reflect in the original object.
